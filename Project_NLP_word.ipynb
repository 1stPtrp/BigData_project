# %% [markdown]
# <a href="https://colab.research.google.com/github/1stPtrp/BigData_project/blob/master/Project_NLP_word.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.preprocessing import text, sequence
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Activation
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import Conv1D, GlobalMaxPooling1D, MaxPooling1D
from sklearn.model_selection import train_test_split
import re
print(tf.__version__)
# Out:
# 2.3.0

# %%
# !wget -O train.csv https://raw.githubusercontent.com/1stPtrp/BigData_project/master/train.csv

# !wget -O test.csv https://raw.githubusercontent.com/1stPtrp/BigData_project/master/test.csv
# Out:
# --2020-11-07 12:00:26--  https://raw.githubusercontent.com/1stPtrp/BigData_project/master/train.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 987712 (965K) [text/plain]
# Saving to: ‘train.csv’
#
# train.csv           100%[===================>] 964.56K  --.-KB/s    in 0.1s
#
# 2020-11-07 12:00:26 (7.48 MB/s) - ‘train.csv’ saved [987712/987712]
#
# --2020-11-07 12:00:26--  https://raw.githubusercontent.com/1stPtrp/BigData_project/master/test.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 420783 (411K) [text/plain]
# Saving to: ‘test.csv’
#
# test.csv            100%[===================>] 410.92K  --.-KB/s    in 0.07s
#
# 2020-11-07 12:00:27 (6.15 MB/s) - ‘test.csv’ saved [420783/420783]

# %%
# Load Data
filePath = "/content/train.csv"
train_df = pd.read_csv(filePath).fillna(' ')
train_df.sample(10, random_state=1)
# Out:
#          id  ... target
# 3228   4632  ...      1
# 3706   5271  ...      0
# 6957   9982  ...      0
# 2887   4149  ...      0
# 7464  10680  ...      1
# 2539   3643  ...      0
# 6837   9794  ...      1
# 7386  10570  ...      0
# 1506   2174  ...      1
# 1875   2694  ...      0
#
# [10 rows x 5 columns]

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
texts = train_df['text'].loc[train_df['target']==1].values
wordcloud = WordCloud(
    width = 640,
    height = 640,
    background_color = 'black',
    stopwords = STOPWORDS).generate(str(texts))
fig = plt.figure(
    figsize =(12, 8),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
texts = train_df['text'].loc[train_df['target']==0].values
wordcloud = WordCloud(
    width = 640,
    height = 640,
    background_color = 'white',
    stopwords = STOPWORDS).generate(str(texts))
fig = plt.figure(
    figsize =(12, 8),
    facecolor = 'k',
    edgecolor = 'k')
plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
puncts = [
    ',', '.', '"', ':', ')', '(', '-', '!', '?', '|', ';', "'", '$', '&',
    '/', '[', ']', '%', '=', '#', '*', '+', '\\', '•', '~', '@', '£',
    '·', '_', '{', '}', '©', '^', '®', '`', '→', '°', '€', '™', '›',
    '♥', '←', '×', '§', '″', '′', 'Â', '█', 'à', '…', '“', '★', '”',
    '–', '●', 'â', '►', '−', '¢', '¬', '░', '¶', '↑', '±',  '▾',
    '═', '¦', '║', '―', '¥', '▓', '—', '‹', '─', '▒', '：', '⊕', '▼',
    '▪', '†', '■', '’', '▀', '¨', '▄', '♫', '☆', 'é', '¯', '♦', '¤', '▲',
    'è', '¸', 'Ã', '⋅', '‘', '∞', '∙', '）', '↓', '、', '│', '（', '»',
    '，', '♪', '╩', '╚', '³', '・', '╦', '╣', '╔', '╗', '▬', '❤', 'ï', 'Ø',
    '¹', '≤', '‡', '₹', '´'
]

# %%
# %%time
def clean_punct(x):
    for punct in puncts:
        if punct in x:
            x = x.replace(punct, f' {punct} ')
    return x
train_df["text"] = train_df["text"].apply(lambda x: clean_punct(x))
# Out:
# CPU times: user 60.9 ms, sys: 1.6 ms, total: 62.5 ms
# Wall time: 63.2 ms

# %%
def remove_URL(text):
    url = re.compile(r'https?://\S+|www\.\S+')
    return url.sub(r'', text)


def remove_emoji(text):
    emoji_pattern = re.compile(
        '['
        u'\U0001F600-\U0001F64F'  # emoticons
        u'\U0001F300-\U0001F5FF'  # symbols & pictographs
        u'\U0001F680-\U0001F6FF'  # transport & map symbols
        u'\U0001F1E0-\U0001F1FF'  # flags (iOS)
        u'\U00002702-\U000027B0'
        u'\U000024C2-\U0001F251'
        ']+',
        flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)


def remove_html(text):
    html = re.compile(r'<.*?>|&([a-z0-9]+|#[0-9]{1,6}|#x[0-9a-f]{1,6});')
    return re.sub(html, '', text)

# %%
train_df["text"] = train_df["text"].apply(lambda x: remove_URL(x))
train_df["text"] = train_df["text"].apply(lambda x: remove_emoji(x))
train_df["text"] = train_df["text"].apply(lambda x: remove_html(x))

# %%
max_features = 20000
max_text_length = 400

# %%
x = train_df['text'].values
print(x)
# Out:
# ['Our Deeds are the Reason of this  # earthquake May ALLAH Forgive us all'
#  'Forest fire near La Ronge Sask .  Canada'
#  "All residents asked to  ' shelter in place '  are being notified by officers .  No other evacuation or shelter in place orders are expected"
#  ...
#  'M1 . 94  [ 01 : 04 UTC ]  ? 5km S of Volcano Hawaii .  http :  /  / t . co / zDtoyd8EbJ'
#  'Police investigating after an e - bike collided with a car in Little Portugal .  E - bike rider suffered serious non - life threatening injuries . '
#  'The Latest :  More Homes Razed by Northern California Wildfire  -  ABC News http :  /  / t . co / YmY4rSkQ3d']

# %%
x_tokenizer = text.Tokenizer(max_features)
x_tokenizer.fit_on_texts(list(x))
x_tokenized = x_tokenizer.texts_to_sequences(x)
x_train_val = sequence.pad_sequences(x_tokenized, maxlen=max_text_length)

# %%
# !wget http://wikipedia2vec.s3.amazonaws.com/models/en/2018-04-20/enwiki_20180420_300d.txt.bz2
# Out:
# --2020-11-07 11:10:10--  http://wikipedia2vec.s3.amazonaws.com/models/en/2018-04-20/enwiki_20180420_300d.txt.bz2
# Resolving wikipedia2vec.s3.amazonaws.com (wikipedia2vec.s3.amazonaws.com)... 52.219.1.37
# Connecting to wikipedia2vec.s3.amazonaws.com (wikipedia2vec.s3.amazonaws.com)|52.219.1.37|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2558818654 (2.4G) [application/x-bzip2]
# Saving to: ‘enwiki_20180420_300d.txt.bz2’
#
# enwiki_20180420_300 100%[===================>]   2.38G  18.5MB/s    in 2m 14s
#
# 2020-11-07 11:12:25 (18.3 MB/s) - ‘enwiki_20180420_300d.txt.bz2’ saved [2558818654/2558818654]

# %%
# !bzip2 -d "/content/enwiki_20180420_300d.txt.bz2"

# %%
# !wget https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz
# Out:
# --2020-11-07 11:23:45--  https://s3.amazonaws.com/dl4j-distribution/GoogleNews-vectors-negative300.bin.gz
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.11.150
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.11.150|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1647046227 (1.5G) [application/x-gzip]
# Saving to: ‘GoogleNews-vectors-negative300.bin.gz’
#
# GoogleNews-vectors- 100%[===================>]   1.53G  78.9MB/s    in 25s
#
# 2020-11-07 11:24:10 (62.5 MB/s) - ‘GoogleNews-vectors-negative300.bin.gz’ saved [1647046227/1647046227]

# %%
import gensim
#Load pretrained vectors from Google
model = gensim.models.KeyedVectors.load_word2vec_format('/content/GoogleNews-vectors-negative300.bin.gz', binary=True)

# %%
model.save("word2vec.model")

# %%
model.word_vec
# Out:
# <bound method WordEmbeddingsKeyedVectors.word_vec of <gensim.models.keyedvectors.Word2VecKeyedVectors object at 0x7f1ed8682400>>

# %%
from gensim.models.keyedvectors import KeyedVectors

model = KeyedVectors.load_word2vec_format('/content/GoogleNews-vectors-negative300.bin.gz', binary=True)
model.save_word2vec_format('/content/GoogleNews-vectors-negative300.txt', binary=False)

# %%
embedding_dim = 300
embeddings_index = dict()
f = open('/content/GoogleNews-vectors-negative300.txt')
for line in f:
  values = line.split()
  word = values[0]
  coefs = np.asarray(values[1:], dtype='float32')
  embeddings_index[word] = coefs
f.close()
print(f'Found {len(embeddings_index)} word vectors.')
# Out:
# Found 3000000 word vectors.

# %%
embedding_matrix = np.zeros((max_features, embedding_dim))
for word, index in x_tokenizer.word_index.items():
  if index > max_features -1:
      break
  else:
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
      embedding_matrix[index] = embedding_vector

# %%
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.6/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.6/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     490         """
# --> 491         parts = [self.recv(flags, copy=copy, track=track)]
#     492         # have first part already, only loop while more to receive
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.recv()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._recv_copy()
#
# /usr/local/lib/python3.6/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-d5df0069828e> in <module>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, use_metadata_server)
#     251       with _output.use_tags('dfs-auth-dance'):
#     252         with open(fifo, 'w') as fifo_file:
# --> 253           fifo_file.write(get_code(auth_prompt) + '\n')
#     254       wrote_to_fifo = True
#     255     elif case == 5:
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     702             self._parent_ident,
#     703             self._parent_header,
# --> 704             password=False,
#     705         )
#     706
#
# /usr/local/lib/python3.6/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     732             except KeyboardInterrupt:
#     733                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 734                 raise KeyboardInterrupt
#     735             else:
#     736                 break
#
# KeyboardInterrupt:

# %%
model = Sequential()
model.add(Embedding(max_features,
                    embedding_dim,
                    embeddings_initializer=tf.keras.initializers.Constant(
                    embedding_matrix),
                    trainable=False))
model.add(Dropout(0.2))

# %%
filters = 250
kernel_size = 3
hidden_dims = 250

# %%
model.add(Conv1D(filters,
                 kernel_size,
                 padding='valid'))
model.add(MaxPooling1D())
model.add(Conv1D(filters,
                 5,
                 padding='valid',
                 activation='relu'))
model.add(GlobalMaxPooling1D())
model.add(Dense(hidden_dims, activation='relu'))
model.add(Dropout(0.2))

model.add(Dense(1, activation='sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, None, 300)         6000000
# _________________________________________________________________
# dropout (Dropout)            (None, None, 300)         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, None, 250)         225250
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, None, 250)         0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, None, 250)         312750
# _________________________________________________________________
# global_max_pooling1d (Global (None, 250)               0
# _________________________________________________________________
# dense (Dense)                (None, 250)               62750
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 250)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 251
# =================================================================
# Total params: 6,601,001
# Trainable params: 601,001
# Non-trainable params: 6,000,000
# _________________________________________________________________

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
y = train_df['target'].values
print(y)
# Out:
# [1 1 1 ... 1 1 1]

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train_val, y,
                                                  test_size=0.15, random_state=1)

# %%
# %%time
batch_size = 32
epochs = 100

history = model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          validation_data= (x_val, y_val))
# Out:
# Epoch 1/100
# 203/203 [==============================] - 111s 545ms/step - loss: 0.4801 - accuracy: 0.7769 - val_loss: 0.4646 - val_accuracy: 0.7986
# Epoch 2/100
# 203/203 [==============================] - 111s 546ms/step - loss: 0.4067 - accuracy: 0.8209 - val_loss: 0.4471 - val_accuracy: 0.8100
# Epoch 3/100
# 203/203 [==============================] - 115s 566ms/step - loss: 0.3462 - accuracy: 0.8546 - val_loss: 0.4553 - val_accuracy: 0.8152
# Epoch 4/100
# 203/203 [==============================] - 110s 543ms/step - loss: 0.2866 - accuracy: 0.8855 - val_loss: 0.4894 - val_accuracy: 0.8030
# Epoch 5/100
# 203/203 [==============================] - 111s 545ms/step - loss: 0.2186 - accuracy: 0.9169 - val_loss: 0.7665 - val_accuracy: 0.7531
# Epoch 6/100
# 203/203 [==============================] - 111s 544ms/step - loss: 0.1689 - accuracy: 0.9379 - val_loss: 0.6474 - val_accuracy: 0.8065
# Epoch 7/100
# 203/203 [==============================] - 110s 543ms/step - loss: 0.1249 - accuracy: 0.9543 - val_loss: 0.7147 - val_accuracy: 0.7872
# Epoch 8/100
# 203/203 [==============================] - 111s 546ms/step - loss: 0.1043 - accuracy: 0.9606 - val_loss: 0.7553 - val_accuracy: 0.7872
# Epoch 9/100
# 203/203 [==============================] - 110s 542ms/step - loss: 0.0940 - accuracy: 0.9623 - val_loss: 0.8231 - val_accuracy: 0.7732
# Epoch 10/100
# 203/203 [==============================] - 110s 543ms/step - loss: 0.0813 - accuracy: 0.9669 - val_loss: 0.9569 - val_accuracy: 0.7933
# Epoch 11/100
# 203/203 [==============================] - 111s 548ms/step - loss: 0.0796 - accuracy: 0.9683 - val_loss: 0.8214 - val_accuracy: 0.7680
# Epoch 12/100
# 203/203 [==============================] - 110s 543ms/step - loss: 0.0713 - accuracy: 0.9720 - val_loss: 1.1236 - val_accuracy: 0.8021
# Epoch 13/100
# 203/203 [==============================] - 110s 543ms/step - loss: 0.0695 - accuracy: 0.9720 - val_loss: 0.9053 - val_accuracy: 0.7951
# Epoch 14/100
# 203/203 [==============================] - 111s 545ms/step - loss: 0.0712 - accuracy: 0.9702 - val_loss: 0.9523 - val_accuracy: 0.7881
# Epoch 15/100
# 203/203 [==============================] - 111s 545ms/step - loss: 0.0644 - accuracy: 0.9719 - val_loss: 1.2223 - val_accuracy: 0.8047
# Epoch 16/100
# 203/203 [==============================] - 111s 547ms/step - loss: 0.0609 - accuracy: 0.9740 - val_loss: 1.2809 - val_accuracy: 0.8065
# Epoch 17/100
# 203/203 [==============================] - 111s 544ms/step - loss: 0.0627 - accuracy: 0.9759 - val_loss: 1.2294 - val_accuracy: 0.7881
# Epoch 18/100
# 203/203 [==============================] - 110s 543ms/step - loss: 0.0536 - accuracy: 0.9765 - val_loss: 1.2319 - val_accuracy: 0.7881
# Epoch 19/100
# 203/203 [==============================] - 111s 546ms/step - loss: 0.0598 - accuracy: 0.9745 - val_loss: 1.2466 - val_accuracy: 0.7890
# Epoch 20/100
# 203/203 [==============================] - 111s 545ms/step - loss: 0.0599 - accuracy: 0.9748 - val_loss: 1.1485 - val_accuracy: 0.7995
# Epoch 21/100
# 203/203 [==============================] - 110s 543ms/step - loss: 0.0600 - accuracy: 0.9754 - val_loss: 1.1184 - val_accuracy: 0.7680
# Epoch 22/100
# 203/203 [==============================] - 111s 545ms/step - loss: 0.0517 - accuracy: 0.9764 - val_loss: 1.5199 - val_accuracy: 0.8056
# Epoch 23/100
# 203/203 [==============================] - 110s 542ms/step - loss: 0.0583 - accuracy: 0.9751 - val_loss: 1.3159 - val_accuracy: 0.8039
# Epoch 24/100
# 203/203 [==============================] - 110s 542ms/step - loss: 0.0455 - accuracy: 0.9785 - val_loss: 1.2100 - val_accuracy: 0.7907
# Epoch 25/100
# 203/203 [==============================] - 111s 545ms/step - loss: 0.0558 - accuracy: 0.9770 - val_loss: 0.9900 - val_accuracy: 0.8039
# Epoch 26/100
# 203/203 [==============================] - 110s 542ms/step - loss: 0.
# Epoch 71/100
# 203/203 [==============================] - 112s 551ms/step - loss: 0.0347 - accuracy: 0.9845 - val_loss: 1.7307 - val_accuracy: 0.7741
# Epoch 72/100
# 203/203 [==============================] - 112s 552ms/step - loss: 0.0317 - accuracy: 0.9838 - val_loss: 1.8577 - val_accuracy: 0.7811
# Epoch 73/100
# 203/203 [==============================] - 113s 557ms/step - loss: 0.0313 - accuracy: 0.9852 - val_loss: 2.2218 - val_accuracy: 0.7890
# Epoch 74/100
# 203/203 [==============================] - 112s 554ms/step - loss: 0.0329 - accuracy: 0.9839 - val_loss: 2.1894 - val_accuracy: 0.7907
# Epoch 75/100
# 203/203 [==============================] - 113s 557ms/step - loss: 0.0372 - accuracy: 0.9836 - val_loss: 1.8485 - val_accuracy: 0.7898
# Epoch 76/100
# 203/203 [==============================] - 113s 558ms/step - loss: 0.0300 - accuracy: 0.9844 - val_loss: 1.8359 - val_accuracy: 0.7855
# Epoch 77/100
# 203/203 [==============================] - 112s 554ms/step - loss: 0.0346 - accuracy: 0.9841 - val_loss: 2.0382 - val_accuracy: 0.7925
# Epoch 78/100
# 203/203 [==============================] - 111s 547ms/step - loss: 0.0342 - accuracy: 0.9841 - val_loss: 1.8898 - val_accuracy: 0.7881
# Epoch 79/100
# 203/203 [==============================] - 111s 547ms/step - loss: 0.0486 - accuracy: 0.9784 - val_loss: 1.5350 - val_accuracy: 0.7846
# Epoch 80/100
# 203/203 [==============================] - 110s 542ms/step - loss: 0.0350 - accuracy: 0.9822 - val_loss: 1.8265 - val_accuracy: 0.7802
# Epoch 81/100
# 203/203 [==============================] - 110s 541ms/step - loss: 0.0372 - accuracy: 0.9838 - val_loss: 1.9137 - val_accuracy: 0.7898
# Epoch 82/100
# 203/203 [==============================] - 110s 542ms/step - loss: 0.0441 - accuracy: 0.9836 - val_loss: 1.8173 - val_accuracy: 0.7960
# Epoch 83/100
# 203/203 [==============================] - 110s 542ms/step - loss: 0.0345 - accuracy: 0.9836 - val_loss: 1.9440 - val_accuracy: 0.7977
# Epoch 84/100
# 203/203 [==============================] - 110s 541ms/step - loss: 0.0382 - accuracy: 0.9815 - val_loss: 1.6063 - val_accuracy: 0.7820
# Epoch 85/100
# 203/203 [==============================] - 111s 544ms/step - loss: 0.0347 - accuracy: 0.9841 - val_loss: 1.8700 - val_accuracy: 0.7750
# Epoch 86/100
# 203/203 [==============================] - 110s 543ms/step - loss: 0.0376 - accuracy: 0.9838 - val_loss: 1.5552 - val_accuracy: 0.7872
# Epoch 87/100
# 203/203 [==============================] - 110s 544ms/step - loss: 0.0355 - accuracy: 0.9833 - val_loss: 1.8797 - val_accuracy: 0.7933
# Epoch 88/100
# 203/203 [==============================] - 111s 545ms/step - loss: 0.0299 - accuracy: 0.9853 - val_loss: 1.7979 - val_accuracy: 0.7977
# Epoch 89/100
# 203/203 [==============================] - 110s 543ms/step - loss: 0.0302 - accuracy: 0.9855 - val_loss: 2.2737 - val_accuracy: 0.8047
# Epoch 90/100
# 203/203 [==============================] - 110s 543ms/step - loss: 0.0325 - accuracy: 0.9839 - val_loss: 2.2069 - val_accuracy: 0.7863
# Epoch 91/100
# 203/203 [==============================] - 111s 545ms/step - loss: 0.0399 - accuracy: 0.9828 - val_loss: 1.6974 - val_accuracy: 0.7890
# Epoch 92/100
# 203/203 [==============================] - 110s 542ms/step - loss: 0.0341 - accuracy: 0.9859 - val_loss: 1.4858 - val_accuracy: 0.7776
# Epoch 93/100
# 203/203 [==============================] - 112s 550ms/step - loss: 0.0303 - accuracy: 0.9852 - val_loss: 1.8947 - val_accuracy: 0.7846
# Epoch 94/100
# 203/203 [==============================] - 111s 545ms/step - loss: 0.0337 - accuracy: 0.9839 - val_loss: 2.4428 - val_accuracy: 0.7933
# Epoch 95/100
# 203/203 [==============================] - 114s 563ms/step - loss: 0.0361 - accuracy: 0.9832 - val_loss: 2.1628 - val_accuracy: 0.7933
# Epoch 96/100
# 203/203 [==============================] - 111s 548ms/step - loss: 0.0352 - accuracy: 0.9828 - val_loss: 1.7306 - val_accuracy: 0.8065
# Epoch 97/100
# 203/203 [==============================] - 111s 547ms/step - loss: 0.0362 - accuracy: 0.9828 - val_loss: 1.6691 - val_accuracy: 0.7863
# Epoch 98/100
# 203/203 [==============================] - 112s 551ms/step - loss: 0.0362 - accuracy: 0.9832 - val_loss: 1.7113 - val_accuracy: 0.7925
# Epoch 99/100
# 203/203 [==============================] - 112s 551ms/step - loss: 0.0338 - accuracy: 0.9849 - val_loss: 2.2295 - val_accuracy: 0.7907
# Epoch 100/100
# 203/203 [==============================] - 110s 543ms/step - loss: 0.0337 - accuracy: 0.9844 - val_loss: 1.2600 - val_accuracy: 0.7942
# CPU times: user 5h 52min 20s, sys: 3min 46s, total: 5h 56min 6s
# Wall time: 3h 6min 8s

# %%
val_predictions = model.predict(x_val, verbose=1, batch_size=32)
# Out:
# 36/36 [==============================] - 6s 166ms/step

# %%
val_predictions.shape
# Out:
# (1142, 1)

# %%
val_predictions
# Out:
# array([[9.9689263e-01],
#        [7.0362049e-01],
#        [4.4155791e-01],
#        ...,
#        [9.4749266e-05],
#        [1.0000000e+00],
#        [9.6783364e-01]], dtype=float32)

# %%
from sklearn import metrics
import seaborn as sns

val_predictions_int = val_predictions.round().astype('int')

# %%
from sklearn.metrics import f1_score
f1_score(y_val, val_predictions_int, zero_division=1)
# Out:
# 0.7518479408658922

# %%
# Showing Confusion Matrix
def plot_cm(y_true, y_pred, title, figsize=(5,5)):
    cm = confusion_matrix(y_true, y_pred, labels=np.unique(y_true))
    cm_sum = np.sum(cm, axis=1, keepdims=True)
    cm_perc = cm / cm_sum.astype(float) * 100
    annot = np.empty_like(cm).astype(str)
    nrows, ncols = cm.shape
    for i in range(nrows):
        for j in range(ncols):
            c = cm[i, j]
            p = cm_perc[i, j]
            if i == j:
                s = cm_sum[i]
                annot[i, j] = '%.1f%%\n%d/%d' % (p, c, s)
            elif c == 0:
                annot[i, j] = ''
            else:
                annot[i, j] = '%.1f%%\n%d' % (p, c)
    cm = pd.DataFrame(cm, index=np.unique(y_true), columns=np.unique(y_true))
    cm.index.name = 'Actual'
    cm.columns.name = 'Predicted'
    fig, ax = plt.subplots(figsize=figsize)
    plt.title(title)
    sns.heatmap(cm, cmap= "YlGnBu", annot=annot, fmt='', ax=ax)

# %%
from sklearn.metrics import classification_report,confusion_matrix
# Showing Confusion Matrix
plot_cm(val_predictions_int, y_val, 'Confusion matrix', figsize=(7,7))

# %%
#Import Test dataset
test_df = pd.read_csv('/content/test.csv')

# %%
test_df.shape
# Out:
# (3263, 4)

# %%
test_df["text"] = test_df["text"].apply(lambda x: clean_punct(x))
test_df["text"] = test_df["text"].apply(lambda x: remove_URL(x))
test_df["text"] = test_df["text"].apply(lambda x: remove_emoji(x))
test_df["text"] = test_df["text"].apply(lambda x: remove_html(x))

# %%
x_test = test_df['text'].values

# %%
def predict_writesub(x_test):
    x_test_tokenized = x_tokenizer.texts_to_sequences(x_test)
    x_testing = sequence.pad_sequences(x_test_tokenized, maxlen=max_text_length)
    predictions = model.predict(x_testing, verbose=1, batch_size=32)
    submission = pd.DataFrame({'id': test_df['id'], 'target': predictions.ravel()})
    submission['target'] = np.where(submission['target']  > 0.5, 1, 0)
    submission.to_csv('submit.csv', index = False)
    print(submission.head())
    
predict_writesub(x_test)
# Out:
# 102/102 [==============================] - 17s 171ms/step
#    id  target
# 0   0       1
# 1   2       1
# 2   3       1
# 3   9       1
# 4  11       1

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend(loc=0)
plt.figure()

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend(loc=0)
plt.show()
